# %% [markdown]
# In this notebook, we will go through the salient features of the `openmc.data` package in the Python API. This package enables inspection, analysis, and conversion of nuclear data from ACE files. Most importantly, the package provides a mean to generate HDF5 nuclear data libraries that are used by the transport solver.

# %%
# %matplotlib inline
import os
import sys
from pprint import pprint
import shutil
import subprocess
import urllib.request

import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
from matplotlib.patches import Rectangle
import pandas as pd

# %%
root_folder = os.path.dirname(os.getcwd())
sys.path.append(root_folder)
import openmc.data

# %% [markdown]
# ## Physical Data
#
# Some very helpful physical data is available as part of `openmc.data`: atomic masses, natural abundances, and atomic weights.

# %%
loc = pd.read_csv('/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/xsdir', '/t', header=None)
# Out:
# /Users/y9z/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
loc
# Out:
#                                                       0
# 0     1001.00c 0.999167 Lib80x/H/1001.800nc 0 1 3 10...
# 1     1001.01c 0.999167 Lib80x/H/1001.801nc 0 1 3 10...
# 2     1001.02c 0.999167 Lib80x/H/1001.802nc 0 1 3 10...
# 3     1001.03c 0.999167 Lib80x/H/1001.803nc 0 1 3 10...
# 4     1001.04c 0.999167 Lib80x/H/1001.804nc 0 1 3 10...
# 5     1001.05c 0.999167 Lib80x/H/1001.805nc 0 1 3 10...
# 6     1001.06c 0.999167 Lib80x/H/1001.806nc 0 1 3 10...
# 7     1002.00c 1.9968 Lib80x/H/1002.800nc 0 1 3 4375...
# 8     1002.01c 1.9968 Lib80x/H/1002.801nc 0 1 3 4392...
# 9     1002.02c 1.9968 Lib80x/H/1002.802nc 0 1 3 4398...
# 10    1002.03c 1.9968 Lib80x/H/1002.803nc 0 1 3 4407...
# 11    1002.04c 1.9968 Lib80x/H/1002.804nc 0 1 3 4420...
# 12    1002.05c 1.9968 Lib80x/H/1002.805nc 0 1 3 4300...
# 13    1002.06c 1.9968 Lib80x/H/1002.806nc 0 1 3 4371...
# 14    1003.00c 2.989596 Lib80x/H/1003.800nc 0 1 3 17...
# 15    1003.01c 2.989596 Lib80x/H/1003.801nc 0 1 3 17...
# 16    1003.02c 2.989596 Lib80x/H/1003.802nc 0 1 3 17...
# 17    1003.03c 2.989596 Lib80x/H/1003.803nc 0 1 3 17...
# 18    1003.04c 2.989596 Lib80x/H/1003.804nc 0 1 3 18...
# 19    1003.05c 2.989596 Lib80x/H/1003.805nc 0 1 3 16...
# 20    1003.06c 2.989596 Lib80x/H/1003.806nc 0 1 3 17...
# 21    2003.00c 2.989032 Lib80x/He/2003.800nc 0 1 3 1...
# 22    2003.01c 2.989032 Lib80x/He/2003.801nc 0 1 3 1...
# 23    2003.02c 2.989032 Lib80x/He/2003.802nc 0 1 3 1...
# 24    2003.03c 2.989032 Lib80x/He/2003.803nc 0 1 3 1...
# 25    2003.04c 2.989032 Lib80x/He/2003.804nc 0 1 3 1...
# 26    2003.05c 2.989032 Lib80x/He/2003.805nc 0 1 3 9...
# 27    2003.06c 2.989032 Lib80x/He/2003.806nc 0 1 3 1...
# 28    2004.00c 3.968219 Lib80x/He/2004.800nc 0 1 3 1...
# 29    2004.01c 3.968219 Lib80x/He/2004.801nc 0 1 3 1...
# ...                                                 ...
# 5705  99253.05c 250.911 Lib80x/Es/99253.805nc 0 1 3 ...
# 5706  99253.06c 250.911 Lib80x/Es/99253.806nc 0 1 3 ...
# 5707  99254.00c 251.905 Lib80x/Es/99254.800nc 0 1 3 ...
# 5708  99254.01c 251.905 Lib80x/Es/99254.801nc 0 1 3 ...
# 5709  99254.02c 251.905 Lib80x/Es/99254.802nc 0 1 3 ...
# 5710  99254.03c 251.905 Lib80x/Es/99254.803nc 0 1 3 ...
# 5711  99254.04c 251.905 Lib80x/Es/99254.804nc 0 1 3 ...
# 5712  99254.05c 251.905 Lib80x/Es/99254.805nc 0 1 3 ...
# 5713  99254.06c 251.905 Lib80x/Es/99254.806nc 0 1 3 ...
# 5714  99654.00c 251.905 Lib80x/Es/1099254.800nc 0 1 ...
# 5715  99654.01c 251.905 Lib80x/Es/1099254.801nc 0 1 ...
# 5716  99654.02c 251.905 Lib80x/Es/1099254.802nc 0 1 ...
# 5717  99654.03c 251.905 Lib80x/Es/1099254.803nc 0 1 ...
# 5718  99654.04c 251.905 Lib80x/Es/1099254.804nc 0 1 ...
# 5719  99654.05c 251.905 Lib80x/Es/1099254.805nc 0 1 ...
# 5720  99654.06c 251.905 Lib80x/Es/1099254.806nc 0 1 ...
# 5721  99255.00c 252.899 Lib80x/Es/99255.800nc 0 1 3 ...
# 5722  99255.01c 252.899 Lib80x/Es/99255.801nc 0 1 3 ...
# 5723  99255.02c 252.899 Lib80x/Es/99255.802nc 0 1 3 ...
# 5724  99255.03c 252.899 Lib80x/Es/99255.803nc 0 1 3 ...
# 5725  99255.04c 252.899 Lib80x/Es/99255.804nc 0 1 3 ...
# 5726  99255.05c 252.899 Lib80x/Es/99255.805nc 0 1 3 ...
# 5727  99255.06c 252.899 Lib80x/Es/99255.806nc 0 1 3 ...
# 5728  100255.00c 252.899 Lib80x/Fm/100255.800nc 0 1 ...
# 5729  100255.01c 252.899 Lib80x/Fm/100255.801nc 0 1 ...
# 5730  100255.02c 252.899 Lib80x/Fm/100255.802nc 0 1 ...
# 5731  100255.03c 252.899 Lib80x/Fm/100255.803nc 0 1 ...
# 5732  100255.04c 252.899 Lib80x/Fm/100255.804nc 0 1 ...
# 5733  100255.05c 252.899 Lib80x/Fm/100255.805nc 0 1 ...
# 5734  100255.06c 252.899 Lib80x/Fm/100255.806nc 0 1 ...
#
# [5735 rows x 1 columns]

# %%
def get_temp(path):
    _temp_key = path[-3]
    temp_dict = {
        '0': '294K',
        '1': '600K',
        '2': '900K',
        '3': '1200K',
        '4': '2500K',
        '5': '0.1K',
        '6': '250K',
    }
    return temp_dict[_temp_key]

# %%
cwd = '/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/'
for each in loc[0]:
    if each.count(' ')>1:
        sp = each.split(' ')
        temp = get_temp(sp[2])
        print(temp)
        print(cwd+sp[2])
# Out:
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1001.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1002.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/H/1003.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2003.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/He/2004.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3006.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Li/3007.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4007.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Be/4009.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5011.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6012.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/C/6013.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7014.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/N/7015.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8016.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8017.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/O/8018.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/F/9019.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10020.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10021.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ne/10022.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11022.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Na/11023.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12024.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12025.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mg/12026.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/1013026.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Al/13027.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14028.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14029.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14030.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14031.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Si/14032.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/P/15031.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16032.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16033.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16034.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16035.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/S/16036.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17035.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17036.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cl/17037.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18036.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18037.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18038.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18039.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18040.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ar/18041.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19039.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19040.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/K/19041.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20040.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20041.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20042.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20043.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20044.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20045.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20046.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20047.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ca/20048.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Sc/21045.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22046.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22047.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22048.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22049.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ti/22050.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23049.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23050.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/V/23051.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24050.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24051.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24052.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24053.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cr/24054.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25054.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Mn/25055.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26054.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26055.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26056.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26057.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fe/26058.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27058.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/1027058.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Co/27059.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28058.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28059.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28060.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28061.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ni/28062.800nc
# 600K
# ...
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96243.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96243.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96243.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96244.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96245.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96246.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96247.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96248.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96249.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cm/96250.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97245.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97246.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97247.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97248.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97249.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Bk/97250.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98246.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98247.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98248.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98249.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98250.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98251.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98252.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98253.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Cf/98254.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99251.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99252.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99253.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99254.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/1099254.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Es/99255.806nc
# 294K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.800nc
# 600K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.801nc
# 900K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.802nc
# 1200K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.803nc
# 2500K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.804nc
# 0.1K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.805nc
# 250K
# /Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Fm/100255.806nc

# %%
def get_data(path):
    ace = openmc.data.IncidentNeutron.from_ace(path, metastable_scheme='mcnp')
    temp = get_temp(path)
    df = pd.DataFrame()
#     df = pd.DataFrame(dtype='float32')
    _energy = ace.energy[temp]
    _total_xs = ace[1].xs[temp](_energy)
#     df[ace.atomic_symbol] = ['E_eV']
#     df[ace.mass_number] = ['Sig_b']
#     df1[ace.atomic_symbol] = _energy
#     df1[ace.mass_number] = _total_xs
#     df = df.append(df1)
    df['E_eV'] = _energy
    df['Sig_b'] = _total_xs
    name = ace.name
    if '_' in name:
        fname= ace.atomic_symbol + '-' + str(ace.mass_number) + '_' + name.split('_')[-1] + '.csv'
    else:
        fname= ace.atomic_symbol + '-' + str(ace.mass_number) + '.csv'
    sub_dir = temp
    if not os.path.exists(sub_dir):
        os.makedirs(sub_dir)
    df.to_csv(temp + '/' + fname, index=False, float_format='%g')
#     df.to_csv(temp + '/' + fname, index=False, float_format='%.10f')
#     df.to_csv(temp + '/' + fname, index=False, float_format='%f')
#     df.to_csv(temp + '/' + fname, index=False)

# %%
get_data('/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ag/1047110.800nc')

# %%
path = '/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.800nc'
ace = openmc.data.IncidentNeutron.from_ace(path, metastable_scheme='mcnp')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-04dee1b57ef3> in <module>
#       1 path = '/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/B/5010.800nc'
# ----> 2 ace = openmc.data.IncidentNeutron.from_ace(path, metastable_scheme='mcnp')
#
# ~/Documents/GitHub/openmc/openmc/data/neutron.py in from_ace(cls, ace_or_filename, metastable_scheme)
#     586             ace = ace_or_filename
#     587         else:
# --> 588             ace = get_table(ace_or_filename)
#     589
#     590         # If mass number hasn't been specified, make an educated guess
#
# ~/Documents/GitHub/openmc/openmc/data/ace.py in get_table(filename, name)
#     186
#     187     if name is None:
# --> 188         return Library(filename).tables[0]
#     189     else:
#     190         lib = Library(filename, name)
#
# ~/Documents/GitHub/openmc/openmc/data/ace.py in __init__(self, filename, table_names, verbose)
#     239             fh.close()
#     240             with open(filename, 'r') as fh:
# --> 241                 self._read_ascii(fh, table_names, verbose)
#     242         except UnicodeDecodeError:
#     243             fh.close()
#
# ~/Documents/GitHub/openmc/openmc/data/ace.py in _read_ascii(self, ace_file, table_names, verbose)
#     414                 datastr = ENDF_FLOAT_RE.sub(r'\1e\2', datastr)
#     415                 xss = np.fromstring(datastr, sep=' ')
# --> 416                 assert xss.size == nxs[1] + 1
#     417
#     418             table = Table(name, atomic_weight_ratio, temperature, pairs,
#
# AssertionError:

# %%
df.to_csv('test.csv', index=False)

# %%
ace.atomic_symbol
# Out:
# 'Ag'

# %%
150%100
# Out:
# 50

# %%
150//100
# Out:
# 1

# %%
openmc.data.atomic_mass('Ag107')
# Out:
# 106.905091531

# %%
openmc.data.NATURAL_ABUNDANCE['H2']
# Out:
# 0.00015574

# %%
openmc.data.atomic_weight('C')
# Out:
# 12.011115164864455

# %% [markdown]
# ## The IncidentNeutron class
#
# The most useful class within the `openmc.data` API is `IncidentNeutron`, which stores to continuous-energy incident neutron data. This class has factory methods `from_ace`, `from_endf`, and `from_hdf5` which take a data file on disk and parse it into a hierarchy of classes in memory. To demonstrate this feature, we will download an ACE file (which can be produced with [NJOY 2016](https://github.com/njoy/NJOY2016)) and then load it in using the `IncidentNeutron.from_ace` method.

# %%
ace = openmc.data.IncidentNeutron.from_ace('/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ag/47107.800nc')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-be45816ee6e8> in <module>
# ----> 1 ace = openmc.data.IncidentNeutron.from_ace('/Lib80x/Fm/100255.800nc')
#
# ~/Documents/GitHub/openmc/openmc/data/neutron.py in from_ace(cls, ace_or_filename, metastable_scheme)
#     586             ace = ace_or_filename
#     587         else:
# --> 588             ace = get_table(ace_or_filename)
#     589
#     590         # If mass number hasn't been specified, make an educated guess
#
# ~/Documents/GitHub/openmc/openmc/data/ace.py in get_table(filename, name)
#     186
#     187     if name is None:
# --> 188         return Library(filename).tables[0]
#     189     else:
#     190         lib = Library(filename, name)
#
# ~/Documents/GitHub/openmc/openmc/data/ace.py in __init__(self, filename, table_names, verbose)
#     229         filename = str(filename)
#     230         try:
# --> 231             fh = open(filename, 'rb')
#     232             # Grab 10 lines of the library
#     233             sb = b''.join([fh.readline() for i in range(10)])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Lib80x/Fm/100255.800nc'

# %%
ace
# Out:
# <IncidentNeutron: Ag107>

# %%
ace.mass_number
# Out:
# 107

# %%
ace.name
# Out:
# 'Ag107'

# %%
ace.atomic_symbol
# Out:
# 'Ag'

# %%
ace.atomic_number
# Out:
# 47

# %%
ace.atomic_weight_ratio
# Out:
# 105.987

# %%
ace[1]
# Out:
# <Reaction: MT=1 (n,total)>

# %%
ace[1].xs
# Out:
# {'0K': <openmc.data.function.Tabulated1D at 0x7fbbb95db4a8>}

# %%
energies = ace.energy['294K']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-b3a7a4106110> in <module>
# ----> 1 energies = ace.energy['294K']
#
# KeyError: '294K'

# %%
len(energies)
# Out:
# 45477

# %%
total_xs = ace[1].xs['294K'](energies)

# %%
plt.loglog(energies, total_xs)
plt.xlabel('Energy (eV)')
plt.ylabel('Cross section (b)')
# Out:
# Text(0, 0.5, 'Cross section (b)')

# %%
# Load ACE data into object
gd157 = openmc.data.IncidentNeutron.from_ace('/Users/y9z/Documents/GitHub/openmc/scripts/Lib80x/Lib80x/Ag/47107.800nc')
gd157
# Out:
# <IncidentNeutron: Ag107>

# %% [markdown]
# ### Cross sections

# %% [markdown]
# From Python, it's easy to explore (and modify) the nuclear data. Let's start off by reading the total cross section. Reactions are indexed using their "MT" number -- a unique identifier for each reaction defined by the ENDF-6 format. The MT number for the total cross section is 1.

# %%
total = gd157[1]
total
# Out:
# <Reaction: MT=1 (n,total)>

# %% [markdown]
# Cross sections for each reaction can be stored at multiple temperatures. To see what temperatures are available, we can look at the reaction's `xs` attribute.

# %%
total.xs
# Out:
# {'294K': <openmc.data.function.Tabulated1D at 0x7fe5096db358>}

# %% [markdown]
# To find the cross section at a particular energy, 1 eV for example, simply get the cross section at the appropriate temperature and then call it as a function. Note that our nuclear data uses eV as the unit of energy.

# %%
total.xs['294K'](1.0)
# Out:
# 142.64747

# %%
total.xs['294K'](1.0)
# Out:
# 12.323924

# %% [markdown]
# The `xs` attribute can also be called on an array of energies.

# %%
total.xs['294K']([1.0, 2.0, 3.0])
# Out:
# array([12.323924  , 10.134723  ,  9.05971433])

# %% [markdown]
# A quick way to plot cross sections is to use the `energy` attribute of `IncidentNeutron`. This gives an array of all the energy values used in cross section interpolation for each temperature present.

# %%
gd157.energy
# Out:
# {'294K': array([1.00000e-05, 1.03125e-05, 1.06250e-05, ..., 1.90000e+07,
#         1.95000e+07, 2.00000e+07])}

# %%
energies = gd157.energy['294K']
total_xs = total.xs['294K'](energies)
plt.loglog(energies, total_xs)
plt.xlabel('Energy (eV)')
plt.ylabel('Cross section (b)')
# Out:
# Text(0, 0.5, 'Cross section (b)')

# %% [markdown]
# ### Reaction Data
#
# Most of the interesting data for an `IncidentNeutron` instance is contained within the `reactions` attribute, which is a dictionary mapping MT values to `Reaction` objects.

# %%
pprint(list(gd157.reactions.values())[:10])
# Out:
# [<Reaction: MT=1 (n,total)>,
#  <Reaction: MT=27 (n,absorption)>,
#  <Reaction: MT=2 (n,elastic)>,
#  <Reaction: MT=16 (n,2n)>,
#  <Reaction: MT=17 (n,3n)>,
#  <Reaction: MT=22 (n,na)>,
#  <Reaction: MT=24 (n,2na)>,
#  <Reaction: MT=28 (n,np)>,
#  <Reaction: MT=41 (n,2np)>,
#  <Reaction: MT=51 (n,n1)>]

# %% [markdown]
# Let's suppose we want to look more closely at the (n,2n) reaction. This reaction has an energy threshold

# %%
n2n = gd157[16]
print('Threshold = {} eV'.format(n2n.xs['294K'].x[0]))
# Out:
# Threshold = 6400881.0 eV

# %% [markdown]
# The (n,2n) cross section, like all basic cross sections, is represented by the `Tabulated1D` class. The energy and cross section values in the table can be directly accessed with the `x` and `y` attributes. Using the `x` and `y` has the nice benefit of automatically acounting for reaction thresholds.

# %%
n2n.xs
# Out:
# {'294K': <openmc.data.function.Tabulated1D at 0x14d02f8e9ac8>}

# %%
xs = n2n.xs['294K']
plt.plot(xs.x, xs.y)
plt.xlabel('Energy (eV)')
plt.ylabel('Cross section (b)')
plt.xlim((xs.x[0], xs.x[-1]))
# Out:
# (6400881.0, 20000000.0)

# %% [markdown]
# To get information on the energy and angle distribution of the neutrons emitted in the reaction, we need to look at the `products` attribute.

# %%
n2n.products
# Out:
# [<Product: neutron, emission=prompt, yield=polynomial>,
#  <Product: photon, emission=prompt, yield=tabulated>]

# %%
neutron = n2n.products[0]
neutron.distribution

# %% [markdown]
# We see that the neutrons emitted have a correlated angle-energy distribution. Let's look at the `energy_out` attribute to see what the outgoing energy distributions are.

# %%
dist = neutron.distribution[0]
dist.energy_out
# Out:
# [<openmc.stats.univariate.Tabular at 0x14d02f8e9b38>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8e9c50>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8e9cf8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8e9e48>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f2080>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f22e8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f25f8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f2978>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f2d68>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f9208>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f96d8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8f9ba8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f901160>,
#  <openmc.stats.univariate.Tabular at 0x14d02f901710>,
#  <openmc.stats.univariate.Tabular at 0x14d02f901d30>,
#  <openmc.stats.univariate.Tabular at 0x14d02f9083c8>,
#  <openmc.stats.univariate.Tabular at 0x14d02f908a90>,
#  <openmc.stats.univariate.Tabular at 0x14d02f90f1d0>,
#  <openmc.stats.univariate.Tabular at 0x14d02f90f8d0>,
#  <openmc.stats.univariate.Tabular at 0x14d02f917080>,
#  <openmc.stats.univariate.Tabular at 0x14d02f917828>,
#  <openmc.stats.univariate.Tabular at 0x14d02f91f048>,
#  <openmc.stats.univariate.Tabular at 0x14d02f91f860>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8a70f0>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8a7978>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8af278>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8afa90>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8b6390>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8b6c88>,
#  <openmc.stats.univariate.Tabular at 0x14d02f8be5f8>]

# %% [markdown]
# Here we see we have a tabulated outgoing energy distribution for each incoming energy. Note that the same probability distribution classes that we could use to create a source definition are also used within the `openmc.data` package. Let's plot every fifth distribution to get an idea of what they look like.

# %%
for e_in, e_out_dist in zip(dist.energy[::5], dist.energy_out[::5]):
    plt.semilogy(e_out_dist.x, e_out_dist.p, label='E={:.2f} MeV'.format(e_in/1e6))
plt.ylim(ymax=1e-6)
plt.legend()
plt.xlabel('Outgoing energy (eV)')
plt.ylabel('Probability/eV')
plt.show()

# %% [markdown]
# ### Unresolved resonance probability tables
#
# We can also look at unresolved resonance probability tables which are stored in a `ProbabilityTables` object. In the following example, we'll create a plot showing what the total cross section probability tables look like as a function of incoming energy.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cm = matplotlib.cm.Spectral_r

# Determine size of probability tables
urr = gd157.urr['294K']
n_energy = urr.table.shape[0]
n_band = urr.table.shape[2]

for i in range(n_energy):
    # Get bounds on energy
    if i > 0:
        e_left = urr.energy[i] - 0.5*(urr.energy[i] - urr.energy[i-1])
    else:
        e_left = urr.energy[i] - 0.5*(urr.energy[i+1] - urr.energy[i])

    if i < n_energy - 1:
        e_right = urr.energy[i] + 0.5*(urr.energy[i+1] - urr.energy[i])
    else:
        e_right = urr.energy[i] + 0.5*(urr.energy[i] - urr.energy[i-1])
        
    for j in range(n_band):
        # Determine maximum probability for a single band
        max_prob = np.diff(urr.table[i,0,:]).max()
        
        # Determine bottom of band
        if j > 0:
            xs_bottom = urr.table[i,1,j] - 0.5*(urr.table[i,1,j] - urr.table[i,1,j-1])
            value = (urr.table[i,0,j] - urr.table[i,0,j-1])/max_prob
        else:
            xs_bottom = urr.table[i,1,j] - 0.5*(urr.table[i,1,j+1] - urr.table[i,1,j])
            value = urr.table[i,0,j]/max_prob

        # Determine top of band
        if j < n_band - 1:
            xs_top = urr.table[i,1,j] + 0.5*(urr.table[i,1,j+1] - urr.table[i,1,j])
        else:
            xs_top = urr.table[i,1,j] + 0.5*(urr.table[i,1,j] - urr.table[i,1,j-1])
    
        # Draw rectangle with appropriate color
        ax.add_patch(Rectangle((e_left, xs_bottom), e_right - e_left, xs_top - xs_bottom,
                     color=cm(value)))

# Overlay total cross section
ax.plot(gd157.energy['294K'], total.xs['294K'](gd157.energy['294K']), 'k')

# Make plot pretty and labeled
ax.set_xlim(1.0, 1.0e5)
ax.set_ylim(1e-1, 1e4)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Energy (eV)')
ax.set_ylabel('Cross section(b)')
# Out:
# Text(0,0.5,'Cross section(b)')

# %% [markdown]
# ### Exporting HDF5 data
#
# If you have an instance `IncidentNeutron` that was created from ACE or HDF5 data, you can easily write it to disk using the `export_to_hdf5()` method. This can be used to convert ACE to HDF5 or to take an existing data set and actually modify cross sections.

# %%
gd157.export_to_hdf5('gd157.h5', 'w')

# %% [markdown]
# With few exceptions, the HDF5 file encodes the same data as the ACE file.

# %%
gd157_reconstructed = openmc.data.IncidentNeutron.from_hdf5('gd157.h5')
np.all(gd157[16].xs['294K'].y == gd157_reconstructed[16].xs['294K'].y)
# Out:
# True

# %% [markdown]
# And one of the best parts of using HDF5 is that it is a widely used format with lots of third-party support. You can use `h5py`, for example, to inspect the data.

# %%
h5file = h5py.File('gd157.h5', 'r')
main_group = h5file['Gd157/reactions']
for name, obj in sorted(list(main_group.items()))[:10]:
    if 'reaction_' in name:
        print('{}, {}'.format(name, obj.attrs['label'].decode()))
# Out:
# reaction_002, (n,elastic)
# reaction_016, (n,2n)
# reaction_017, (n,3n)
# reaction_022, (n,na)
# reaction_024, (n,2na)
# reaction_028, (n,np)
# reaction_041, (n,2np)
# reaction_051, (n,n1)
# reaction_052, (n,n2)
# reaction_053, (n,n3)

# %%
n2n_group = main_group['reaction_016']
pprint(list(n2n_group.values()))
# Out:
# [<HDF5 group "/Gd157/reactions/reaction_016/294K" (1 members)>,
#  <HDF5 group "/Gd157/reactions/reaction_016/product_0" (2 members)>,
#  <HDF5 group "/Gd157/reactions/reaction_016/product_1" (2 members)>]

# %% [markdown]
# So we see that the hierarchy of data within the HDF5 mirrors the hierarchy of Python objects that we manipulated before.

# %%
n2n_group['294K/xs'].value
# Out:
# array([0.000000e+00, 3.026796e-13, 1.291101e-02, 6.511110e-02,
#        3.926270e-01, 5.752268e-01, 6.969600e-01, 7.399378e-01,
#        9.635450e-01, 1.142130e+00, 1.308020e+00, 1.463500e+00,
#        1.557600e+00, 1.640550e+00, 1.688960e+00, 1.711400e+00,
#        1.739450e+00, 1.782070e+00, 1.816650e+00, 1.845280e+00,
#        1.865409e+00, 1.867240e+00, 1.881558e+00, 1.881560e+00,
#        1.881800e+00, 1.894470e+00, 1.869570e+00, 1.821200e+00,
#        1.716000e+00, 1.600540e+00, 1.431620e+00, 1.283460e+00,
#        1.101660e+00, 1.065300e+00, 9.307300e-01, 8.029800e-01,
#        7.777400e-01])

# %% [markdown]
# ### Working with ENDF files
#
# In addition to being able to load ACE and HDF5 data, we can also load ENDF data directly into an `IncidentNeutron` instance using the `from_endf()` factory method. Let's download the ENDF/B-VII.1 evaluation for $^{157}$Gd and load it in:

# %%
# Download ENDF file
url = 'https://t2.lanl.gov/nis/data/data/ENDFB-VII.1-neutron/Gd/157'
filename, headers = urllib.request.urlretrieve(url, 'gd157.endf')

# Load into memory
gd157_endf = openmc.data.IncidentNeutron.from_endf(filename)
gd157_endf
# Out:
# <IncidentNeutron: Gd157>

# %% [markdown]
# Just as before, we can get a reaction by indexing the object directly:

# %%
elastic = gd157_endf[2]

# %% [markdown]
# However, if we look at the cross section now, we see that it isn't represented as tabulated data anymore.

# %%
elastic.xs
# Out:
# {'0K': <openmc.data.function.ResonancesWithBackground at 0x14d02ba7dda0>}

# %% [markdown]
# If had [Cython](http://cython.org/) installed when you built/installed OpenMC, you should be able to evaluate resonant cross sections from ENDF data directly, i.e., OpenMC will reconstruct resonances behind the scenes for you.

# %%
elastic.xs['0K'](0.0253)
# Out:
# 998.7871174521487

# %% [markdown]
# When data is loaded from an ENDF file, there is also a special `resonances` attribute that contains resolved and unresolved resonance region data (from MF=2 in an ENDF file).

# %%
gd157_endf.resonances.ranges
# Out:
# [<openmc.data.resonance.ReichMoore at 0x14d02d198e80>,
#  <openmc.data.resonance.Unresolved at 0x14d02d20dcc0>]

# %% [markdown]
# We see that $^{157}$Gd has a resolved resonance region represented in the Reich-Moore format as well as an unresolved resonance region. We can look at the min/max energy of each region by doing the following:

# %%
[(r.energy_min, r.energy_max) for r in gd157_endf.resonances.ranges]
# Out:
# [(1e-05, 306.6), (306.6, 54881.1)]

# %% [markdown]
# With knowledge of the energy bounds, let's create an array of energies over the entire resolved resonance range and plot the elastic scattering cross section.

# %%
# Create log-spaced array of energies
resolved = gd157_endf.resonances.resolved
energies = np.logspace(np.log10(resolved.energy_min),
                       np.log10(resolved.energy_max), 1000)

# Evaluate elastic scattering xs at energies
xs = elastic.xs['0K'](energies)

# Plot cross section vs energies
plt.loglog(energies, xs)
plt.xlabel('Energy (eV)')
plt.ylabel('Cross section (b)')
# Out:
# Text(0,0.5,'Cross section (b)')

# %% [markdown]
# Resonance ranges also have a useful `parameters` attribute that shows the energies and widths for resonances.

# %%
resolved.parameters.head(10)
# Out:
#     energy  L    J  neutronWidth  captureWidth  fissionWidthA  fissionWidthB
# 0   0.0314  0  2.0      0.000474        0.1072            0.0            0.0
# 1   2.8250  0  2.0      0.000345        0.0970            0.0            0.0
# 2  16.2400  0  1.0      0.000400        0.0910            0.0            0.0
# 3  16.7700  0  2.0      0.012800        0.0805            0.0            0.0
# 4  20.5600  0  2.0      0.011360        0.0880            0.0            0.0
# 5  21.6500  0  2.0      0.000376        0.1140            0.0            0.0
# 6  23.3300  0  1.0      0.000813        0.1210            0.0            0.0
# 7  25.4000  0  2.0      0.001840        0.0850            0.0            0.0
# 8  40.1700  0  1.0      0.001307        0.1100            0.0            0.0
# 9  44.2200  0  2.0      0.008960        0.0960            0.0            0.0

# %% [markdown]
# ## Heavy-nuclide resonance scattering
#
# OpenMC has two methods for accounting for resonance upscattering in heavy nuclides, DBRC and RVS. These methods rely on 0 K elastic scattering data being present. If you have an existing ACE/HDF5 dataset and you need to add 0 K elastic scattering data to it, this can be done using the `IncidentNeutron.add_elastic_0K_from_endf()` method. Let's do this with our original `gd157` object that we instantiated from an ACE file.

# %%
gd157.add_elastic_0K_from_endf('gd157.endf')

# %% [markdown]
# Let's check to make sure that we have both the room temperature elastic scattering cross section as well as a 0K cross section.

# %%
gd157[2].xs
# Out:
# {'294K': <openmc.data.function.Tabulated1D at 0x14d02ff8f9b0>,
#  '0K': <openmc.data.function.Tabulated1D at 0x14d02b7ccc50>}

# %% [markdown]
# ## Generating data from NJOY
#
# To run OpenMC in continuous-energy mode, you generally need to have ACE files already available that can be converted to OpenMC's native HDF5 format. If you don't already have suitable ACE files or need to generate new data, both the `IncidentNeutron` and `ThermalScattering` classes include `from_njoy()` methods that will run [NJOY](https://njoy.github.io/NJOY2016/) to generate ACE files and then read those files to create OpenMC class instances. The `from_njoy()` methods take as input the name of an ENDF file on disk. By default, it is assumed that you have an executable named `njoy` available on your path. This can be configured with the optional `njoy_exec` argument. Additionally, if you want to show the progress of NJOY as it is running, you can pass `stdout=True`.
#
# Let's use `IncidentNeutron.from_njoy()` to run NJOY to create data for $^2$H using an ENDF file. We'll specify that we want data specifically at 300, 400, and 500 K.

# %%
# Download ENDF file
url = 'https://t2.lanl.gov/nis/data/data/ENDFB-VII.1-neutron/H/2'
filename, headers = urllib.request.urlretrieve(url, 'h2.endf')

# Run NJOY to create deuterium data
h2 = openmc.data.IncidentNeutron.from_njoy('h2.endf', temperatures=[300., 400., 500.], stdout=True)
# Out:
#  njoy 2016.44  11Oct18                                       11/09/18 20:25:51
#  *****************************************************************************
#
#  reconr...                                                                0.0s
#
#  broadr...                                                                0.1s
#       300.0 deg                                                           0.1s
#       400.0 deg                                                           0.2s
#       500.0 deg                                                           0.3s
#
#  heatr...                                                                 0.4s
#
#  purr...                                                                  0.9s
#
#  mat =  128                                                               0.9s
#
#  ---message from purr---mat  128 has no resonance parameters
#                           copy as is to nout
#
#  acer...                                                                  0.9s
#
#  acer...                                                                  1.1s
#
#  acer...                                                                  1.3s
#                                                                           1.4s
#  *****************************************************************************

# %% [markdown]
# Now we can use our `h2` object just as we did before.

# %%
h2[2].xs
# Out:
# {'300K': <openmc.data.function.Tabulated1D at 0x14d02ab60ba8>,
#  '400K': <openmc.data.function.Tabulated1D at 0x14d02b7b64a8>,
#  '500K': <openmc.data.function.Tabulated1D at 0x14d02b801320>,
#  '0K': <openmc.data.function.Tabulated1D at 0x14d02b81dba8>}

# %% [markdown]
# Note that 0 K elastic scattering data is automatically added when using `from_njoy()` so that resonance elastic scattering treatments can be used.

# %% [markdown]
# ## Windowed multipole
#
# OpenMC can also be used with an experimental format called windowed multipole.  Windowed multipole allows for analytic on-the-fly Doppler broadening of the resolved resonance range.  Windowed multipole data can be downloaded with the `openmc-get-multipole-data` script.  This data can be used in the transport solver, but it can also be used directly in the Python API.

# %%
url = 'https://github.com/mit-crpg/WMP_Library/releases/download/v1.1/092238.h5'
filename, headers = urllib.request.urlretrieve(url, '092238.h5')

# %%
u238_multipole = openmc.data.WindowedMultipole.from_hdf5('092238.h5')

# %% [markdown]
# The `WindowedMultipole` object can be called with energy and temperature values.  Calling the object gives a tuple of 3 cross sections: elastic scattering, radiative capture, and fission.

# %%
u238_multipole(1.0, 294)
# Out:
# (array(9.13284265), array(0.50530278), array(2.9316765e-06))

# %% [markdown]
# An array can be passed for the energy argument.

# %%
E = np.linspace(5, 25, 1000)
plt.semilogy(E, u238_multipole(E, 293.606)[1])

# %% [markdown]
# The real advantage to multipole is that it can be used to generate cross sections at any temperature.  For example, this plot shows the Doppler broadening of the 6.67 eV resonance between 0 K and 900 K.

# %%
E = np.linspace(6.1, 7.1, 1000)
plt.semilogy(E, u238_multipole(E, 0)[1])
plt.semilogy(E, u238_multipole(E, 900)[1])
